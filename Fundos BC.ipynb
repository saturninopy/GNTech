# %%
# EXEMPLO QUANT STATS - RELATÓRIO QUANT

# !pip install quantstats

# %%
# REPORT - Fundo ESG

import quantstats as qs

qs.extend_pandas()

tickers = {
    'EMBR3.SA': 0.296,
    'PETZ3.SA': 0.569, 
    'JBSS3.SA': 0.053,
    'VIVA3.SA': 0.048,
    'NTCO3.SA': 0.035
}

gnasset = qs.utils.make_index(tickers)

qs.reports.html(gnasset, '^BVSP', title='Moderninho Investments vs. IBOV', output='Moderninho_vs_S&P.html')

qs.plots.earnings(gnasset,start_balance=100000)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\quantstats\utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)

# %%
# REPORT - Fundo Profs

qs.extend_pandas()

tickers = {
    'EMBR3.SA': 0.887,
    'PETZ3.SA': 0.067, 
    'JBSS3.SA': 0.053,
    'VIVA3.SA': 0.048,
    'NTCO3.SA': 0.035
}

gnasset = qs.utils.make_index(tickers)

qs.reports.html(gnasset, '^BVSP', title='Malboro Investments vs. IBOV', output='Malboro_vs_IBOV.html')

qs.plots.earnings(gnasset,start_balance=100000)
# Out:
# C:\Users\alexa\anaconda3\lib\site-packages\quantstats\utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)
